# %%
import arukone_gen
import SaveNumlinkFormat
import numpy as np
import time
from datetime import datetime

h, w = 12, 12
print(f"--- {h}x{w} 全マス使用ナンバーリンク作問中 ---")
t0 = time.time()
grid, paths = arukone_gen.build_arukone(h, w)

elapsed = time.time() - t0
print(f"\n★ 完成！ ペア数={len(paths)}  ({elapsed:.2f}秒)")
print(np.array(grid))

SaveNumlinkFormat.save_numlin_format(grid, f"../problems/numlin_w{w}-h{h}_{datetime.now().strftime('%Y%m%d_%H%M%S')}.txt")
print(SaveNumlinkFormat.generate_numlin_url(w, h, [i for r in grid for i in r]))
