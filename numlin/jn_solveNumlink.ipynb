# %%
from NumberLinkSolver import NumberLinkSolver
import SaveNumlinkFormat

# %%
solver = NumberLinkSolver(grid)
solution = solver.solve()

if solution:
    for row in solution:
        print(row)
else:
    print("No solution found.")
# Out:
# [10, 10, 10, 10, 10, 10, 10, 10, 10, 10]
# [6, 6, 6, 6, 6, 6, 6, 6, 6, 6]
# [1, 1, 1, 1, 9, 9, 9, 9, 9, 9]
# [9, 9, 9, 9, 9, 7, 7, 7, 7, 9]
# [9, 5, 4, 4, 7, 7, 3, 2, 7, 8]
# [9, 5, 5, 4, 7, 3, 3, 2, 7, 8]
# [9, 2, 2, 2, 2, 2, 2, 2, 7, 8]
# [9, 8, 8, 8, 8, 8, 8, 7, 7, 8]
# [9, 9, 9, 9, 9, 9, 8, 8, 8, 8]

# %%
grid = SaveNumlinkFormat.load_numlin_format("../problems/numlin_w10-h9-n10_20260314_174837.txt")
w = len(grid[0])
h = len(grid)
print(SaveNumlinkFormat.generate_numlin_url(w, h, [i for r in grid for i in r]))
# Out:
# https://puzz.link/p?numlin/10/9/ana6n61h1u9g54i32g8h5473k2o8k7m9j
